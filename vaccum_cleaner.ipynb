# %% [markdown]
# <a href="https://colab.research.google.com/github/suhana0611/vaccum-cleaner/blob/main/vaccum_cleaner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Agent Table
agent_table = {
    ('Dirty', 'A'): 'Suck',
    ('Dirty', 'B'): 'Suck',
    ('Clean', 'A'): 'Move Right',
    ('Clean', 'B'): 'Move Left'
}

class VacuumCleaner:

    def __init__(self, location='A'):
        self.location = location
        self.room_status = {'A': 'Dirty', 'B': 'Dirty'}

    def percept(self):
        return (self.room_status[self.location], self.location)

    def act(self, action):

        if action == 'Suck':
            self.room_status[self.location] = 'Clean'

        elif action == 'Move Right':
            self.location = 'B'

        elif action == 'Move Left':
            self.location = 'A'

    def get_cleaning_percentage(self):
        total = len(self.room_status)
        clean = sum(1 for status in self.room_status.values() if status == 'Clean')
        return (clean / total) * 100

    def get_overall_status(self):
        if self.get_cleaning_percentage() == 100:
            return "The entire floor is clean"
        else:
            return "The floor is not yet clean"


def table_driven_agent(percept):
    return agent_table.get(percept, 'NoOp')


# Main Program
if __name__ == "__main__":

    vacuum = VacuumCleaner()

    for step in range(5):

        percept = vacuum.percept()
        action = table_driven_agent(percept)

        print(f"Step {step+1}")
        print("Percept:", percept)
        print("Action:", action)

        vacuum.act(action)

        print("Room Status:", vacuum.room_status)
        print("Cleaning Percentage:", vacuum.get_cleaning_percentage(), "%")
        print("-" * 40)

    print("Overall Status:", vacuum.get_overall_status())
# Out:
# Step 1
# Percept: ('Dirty', 'A')
# Action: Suck
# Room Status: {'A': 'Clean', 'B': 'Dirty'}
# Cleaning Percentage: 50.0 %
# ----------------------------------------
# Step 2
# Percept: ('Clean', 'A')
# Action: Move Right
# Room Status: {'A': 'Clean', 'B': 'Dirty'}
# Cleaning Percentage: 50.0 %
# ----------------------------------------
# Step 3
# Percept: ('Dirty', 'B')
# Action: Suck
# Room Status: {'A': 'Clean', 'B': 'Clean'}
# Cleaning Percentage: 100.0 %
# ----------------------------------------
# Step 4
# Percept: ('Clean', 'B')
# Action: Move Left
# Room Status: {'A': 'Clean', 'B': 'Clean'}
# Cleaning Percentage: 100.0 %
# ----------------------------------------
# Step 5
# Percept: ('Clean', 'A')
# Action: Move Right
# Room Status: {'A': 'Clean', 'B': 'Clean'}
# Cleaning Percentage: 100.0 %
# ----------------------------------------
# Overall Status: The entire floor is clean
